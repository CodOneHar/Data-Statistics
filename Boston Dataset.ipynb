# %%
import piplite
await piplite.install(['numpy'])
await piplite.install(['pandas'])
await piplite.install(['seaborn'])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import statsmodels.api as sm

# %%
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
resp = await fetch(URL)
boston_url = io.BytesIO((await resp.arrayBuffer()).to_py())

# %%
boston_df = pd.read_csv(boston_url)

# %%
boston_df.describe()
# Out:
#        Unnamed: 0        CRIM          ZN       INDUS        CHAS         NOX  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean   252.500000    3.613524   11.363636   11.136779    0.069170    0.554695
# std    146.213884    8.601545   23.322453    6.860353    0.253994    0.115878
# min      0.000000    0.006320    0.000000    0.460000    0.000000    0.385000
# 25%    126.250000    0.082045    0.000000    5.190000    0.000000    0.449000
# 50%    252.500000    0.256510    0.000000    9.690000    0.000000    0.538000
# 75%    378.750000    3.677083   12.500000   18.100000    0.000000    0.624000
# max    505.000000   88.976200  100.000000   27.740000    1.000000    0.871000
#
#                RM         AGE         DIS         RAD         TAX     PTRATIO  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     6.284634   68.574901    3.795043    9.549407  408.237154   18.455534
# ...

# %%
boston_df.head(10)
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31   0.0  0.538  6.575   65.2  4.0900  1.0
# 1           1  0.02731   0.0   7.07   0.0  0.469  6.421   78.9  4.9671  2.0
# 2           2  0.02729   0.0   7.07   0.0  0.469  7.185   61.1  4.9671  2.0
# 3           3  0.03237   0.0   2.18   0.0  0.458  6.998   45.8  6.0622  3.0
# 4           4  0.06905   0.0   2.18   0.0  0.458  7.147   54.2  6.0622  3.0
# 5           5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622  3.0
# 6           6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605  5.0
# 7           7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505  5.0
# 8           8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821  5.0
# 9           9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921  5.0
#
#      TAX  PTRATIO  LSTAT  MEDV
# 0  296.0     15.3   4.98  24.0
# 1  242.0     17.8   9.14  21.6
# 2  242.0     17.8   4.03  34.7
# ...

# %%
ax = sns.boxplot(y = 'MEDV', data = boston_df)
ax.set_title('Owner-occupied homes')
# Out:
# Text(0.5, 1.0, 'Owner-occupied homes')

# %%
ax = sns.countplot(x = 'CHAS', data = boston_df)
ax.set_title('Charles River variable (1 if tract bounds river; 0 otherwise)')
# Out:
# Text(0.5, 1.0, 'Charles River variable (1 if tract bounds river; 0 otherwise)')

# %%
boston_df.loc[(boston_df['AGE'] <= 35), 'Age_Group'] = '35 years and younger'
boston_df.loc[(boston_df['AGE'] > 35) & (boston_df['AGE'] < 70), 'Age_Group'] = 'between 35 and 70 years'
boston_df.loc[(boston_df['AGE'] >= 70), 'Age_Group'] = '70 years and older'

# %%
ax = sns.boxplot(x = 'MEDV', y = 'Age_Group', data = boston_df)
ax.set_title('Median value of owner-occupied homes per Age Group')
# Out:
# Text(0.5, 1.0, 'Median value of owner-occupied homes per Age Group')

# %%
ax = sns.scatterplot(y = 'NOX', x = 'INDUS', data = boston_df)
ax.set_title('Nitric oxide concentration per proportion of non-retail business acres per town')
# Out:
# Text(0.5, 1.0, 'Nitric oxide concentration per proportion of non-retail business acres per town')

# %%
ax = sns.histplot(data=boston_df, x='PTRATIO').set_title('Pupil to teacher ratio variable')

# %%
import scipy.stats

# %% [markdown]
# ### Is there a significant difference in median value of houses bounded by the Charles river or not?

# %%
scipy.stats.ttest_ind(boston_df[boston_df['CHAS'] == 0]['MEDV'],
                      boston_df[boston_df['CHAS'] == 1]['MEDV'], equal_var=True)
# Out:
# Ttest_indResult(statistic=-3.996437466090509, pvalue=7.390623170519905e-05)

# %% [markdown]
# #### Since p-value is less than 0.05, it is concluded that there is not a statistical difference in median value betwenn houses bounded by the Charles river.

# %% [markdown]
# ### Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)?

# %%
from statsmodels.formula.api import ols
lm = ols('MEDV ~ AGE', data = boston_df).fit()
table = sm.stats.anova_lm(lm)
print(table)
# Out:
#              df        sum_sq      mean_sq          F        PR(>F)
# AGE         1.0   6069.761065  6069.761065  83.477459  1.569982e-18
# Residual  504.0  36646.534350    72.711378        NaN           NaN

# %% [markdown]
# #### Given p-value is less than 0.05, there is no statistical difference in Median values of houses (MEDV) for each proportion of owner occpied units built prior to 1940.

# %% [markdown]
# ### Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town?

# %%
scipy.stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
# Out:
# PearsonRResult(statistic=0.7636514469209189, pvalue=7.913361061211254e-98)

# %% [markdown]
# #### Given the Pearson Coefficient is 0.76365 and p-value less than 0.05, there is no positive correlation between Nitric oxide concentration and proportion of non-retail business acres per town

# %% [markdown]
# ### What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes?

# %%
X = boston_df['DIS']
y = boston_df['MEDV']
X = sm.add_constant(X) 

model = sm.OLS(y, X).fit()
predictions = model.predict(X)

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   MEDV   R-squared:                       0.062
# Model:                            OLS   Adj. R-squared:                  0.061
# Method:                 Least Squares   F-statistic:                     33.58
# Date:                Sun, 13 Aug 2023   Prob (F-statistic):           1.21e-08
# Time:                        03:15:38   Log-Likelihood:                -1823.9
# No. Observations:                 506   AIC:                             3652.
# Df Residuals:                     504   BIC:                             3660.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         18.3901      0.817     22.499      0.000      16.784      19.996
# ...

# %% [markdown]
# #### A positive coefficient (1.0916 in this case) indicates that as the weighted distance to the employment centers increases by one unit, the median value of owner-occupied homes is estimated to increase by approximately 1.0916 units.
